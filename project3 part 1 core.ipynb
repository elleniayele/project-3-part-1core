# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'title-akas-us-only (4).csv',
#  'title.basics (1).tsv.gz',
#  'title.ratings (1).tsv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %%
basics_url=("https://datasets.imdbws.com/title.basics.tsv.gz")
import pandas as pd
import numpy as np

# %%
akas_url="Data/title-akas-us-only (5).csv"

# %%
ratings_url='https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url,sep='\t')
basics.head()
# Out:
# C:\Users\awot1\AppData\Local\Temp\ipykernel_39560\1591897761.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   basics = pd.read_csv(basics_url,sep='\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas = pd.read_csv(akas_url)
akas.head()
# Out:
# C:\Users\awot1\AppData\Local\Temp\ipykernel_39560\2823779435.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   akas = pd.read_csv(akas_url)
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=True)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1856
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2641

# %% [markdown]
# ## reading akas file

# %% [markdown]
# ###Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
   # Filter the basics table down to only include the US by using the filter akas dataframe
keepers = ratings['tconst'].isin(akas['titleId']) 
ratings = ratings[keepers]

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1990
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1856
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2641
# ...            ...            ...       ...
# 1336670  tt9916730            8.3        10
# 1336671  tt9916766            7.0        22
# 1336672  tt9916778            7.2        36
# 1336673  tt9916840            8.8         6
# 1336674  tt9916880            8.2         6
#
# [1336675 rows x 3 columns]

# %% [markdown]
# - Include only movies that were released in the United States.
# - Exclude any movie with missing values for genre or runtime
# - Include only full-length movies (titleType = "movie").
# - Include only movies that were released 2000 - 2021 (include 2000 and 2021)
# - Include only fictional movies (not from the Documentary genre)

# %% [markdown]
# ## working on the basics data frame

# %% [markdown]
# ####Replace "\N" with np.nan

# %%
basics.replace({'\\N':np.nan}, inplace= True)

# %% [markdown]
# ####Eliminate movies that are null for runtimeMinutes

# %%
basics.dropna(subset= "runtimeMinutes")
# Out:
#              tconst  titleType                    primaryTitle  \
# 0         tt0000001      short                      Carmencita
# 1         tt0000002      short          Le clown et ses chiens
# 2         tt0000003      short                  Pauvre Pierrot
# 3         tt0000004      short                     Un bon bock
# 4         tt0000005      short                Blacksmith Scene
# ...             ...        ...                             ...
# 10066924  tt9916754      movie  Chico Albuquerque - Revelações
# 10066930  tt9916766  tvEpisode                  Episode #10.15
# 10066965  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 10066972  tt9916856      short                        The Wind
# 10066973  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear endYear  \
# 0                             Carmencita       0      1894     NaN
# 1                 Le clown et ses chiens       0      1892     NaN
# 2                         Pauvre Pierrot       0      1892     NaN
# 3                            Un bon bock       0      1892     NaN
# 4                       Blacksmith Scene       0      1893     NaN
# ...                                  ...     ...       ...     ...
# 10066924  Chico Albuquerque - Revelações       0      2013     NaN
# 10066930                  Episode #10.15       0      2019     NaN
# 10066965      Horrid Henry's Comic Caper       0      2014     NaN
# 10066972                        The Wind       0      2015     NaN
# 10066973       Horrid Henry Knows It All       0      2014     NaN
#
#          runtimeMinutes                       genres
# 0                     1            Documentary,Short
# 1                     5              Animation,Short
# 2                     4     Animation,Comedy,Romance
# 3                    12              Animation,Short
# 4                     1                 Comedy,Short
# ...                 ...                          ...
# 10066924             49                  Documentary
# 10066930             43  Family,Game-Show,Reality-TV
# 10066965             11   Adventure,Animation,Comedy
# 10066972             27                        Short
# 10066973             10   Adventure,Animation,Comedy
#
# [2991638 rows x 9 columns]

# %%
basics.dropna(subset='genres')
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10066969  tt9916848  tvEpisode              Episode #3.17
# 10066970  tt9916850  tvEpisode              Episode #3.19
# 10066971  tt9916852  tvEpisode              Episode #3.20
# 10066972  tt9916856      short                   The Wind
# 10066973  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894     NaN              1
# 1            Le clown et ses chiens       0      1892     NaN              5
# 2                    Pauvre Pierrot       0      1892     NaN              4
# 3                       Un bon bock       0      1892     NaN             12
# 4                  Blacksmith Scene       0      1893     NaN              1
# ...                             ...     ...       ...     ...            ...
# 10066969              Episode #3.17       0      2009     NaN            NaN
# 10066970              Episode #3.19       0      2010     NaN            NaN
# 10066971              Episode #3.20       0      2010     NaN            NaN
# 10066972                   The Wind       0      2015     NaN             27
# 10066973  Horrid Henry Knows It All       0      2014     NaN             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10066969         Action,Drama,Family
# 10066970         Action,Drama,Family
# 10066971         Action,Drama,Family
# 10066972                       Short
# 10066973  Adventure,Animation,Comedy
#
# [9614811 rows x 9 columns]

# %% [markdown]
# include only full-length movies (titleType = "movie").

# %%
basics= basics[basics['titleType']=='movie']

# %%
basics
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10066865  tt9916622     movie
# 10066892  tt9916680     movie
# 10066904  tt9916706     movie
# 10066914  tt9916730     movie
# 10066924  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 10066865        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10066892  De la ilusión al desconcierto: cine colombiano...
# 10066904                                    Dankyavar Danka
# 10066914                                             6 Gunn
# 10066924                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                Miss Jerry       0      1894
# 144                           The Corbett-Fitzsimmons Fight       0      1897
# 498                                                Bohemios       0      1905
# 570                             The Story of the Kelly Gang       0      1906
# 587                                       L'enfant prodigue       0      1907
# ...                                                     ...     ...       ...
# 10066865        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10066892  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10066904                                    Dankyavar Danka       0      2013
# 10066914                                             6 Gunn       0      2017
# 10066924                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 498          NaN            100                         NaN
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# ...          ...            ...                         ...
# 10066865     NaN             57                 Documentary
# 10066892     NaN            100                 Documentary
# 10066904     NaN            NaN                      Comedy
# 10066914     NaN            116                       Drama
# 10066924     NaN             49                 Documentary
#
# [653410 rows x 9 columns]

# %% [markdown]
# keep startYear 2000-2021

# %%
basics= basics.astype({'startYear':'float'})

# %%
basics=basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]

# %%
basics
# Out:
#              tconst titleType  \
# 11636     tt0011801     movie
# 13081     tt0013274     movie
# 15176     tt0015414     movie
# 34801     tt0035423     movie
# 61113     tt0062336     movie
# ...             ...       ...
# 10066865  tt9916622     movie
# 10066892  tt9916680     movie
# 10066904  tt9916706     movie
# 10066914  tt9916730     movie
# 10066924  tt9916754     movie
#
#                                                primaryTitle  \
# 11636                                      Tötet nicht mehr
# 13081                           Istoriya grazhdanskoy voyny
# 15176                                La tierra de los toros
# 34801                                        Kate & Leopold
# 61113     The Tango of the Widower and Its Distorting Mi...
# ...                                                     ...
# 10066865        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10066892  De la ilusión al desconcierto: cine colombiano...
# 10066904                                    Dankyavar Danka
# 10066914                                             6 Gunn
# 10066924                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult  \
# 11636                                      Tötet nicht mehr       0
# 13081                           Istoriya grazhdanskoy voyny       0
# 15176                                La tierra de los toros       0
# 34801                                        Kate & Leopold       0
# 61113             El tango del viudo y su espejo deformante       0
# ...                                                     ...     ...
# 10066865        Rodolpho Teóphilo - O Legado de um Pioneiro       0
# 10066892  De la ilusión al desconcierto: cine colombiano...       0
# 10066904                                    Dankyavar Danka       0
# 10066914                                             6 Gunn       0
# 10066924                     Chico Albuquerque - Revelações       0
#
#           startYear endYear runtimeMinutes                  genres
# 11636        2019.0     NaN            NaN            Action,Crime
# 13081        2021.0     NaN             94             Documentary
# 15176        2000.0     NaN             60                     NaN
# 34801        2001.0     NaN            118  Comedy,Fantasy,Romance
# 61113        2020.0     NaN             70                   Drama
# ...             ...     ...            ...                     ...
# 10066865     2015.0     NaN             57             Documentary
# 10066892     2007.0     NaN            100             Documentary
# 10066904     2013.0     NaN            NaN                  Comedy
# 10066914     2017.0     NaN            116                   Drama
# 10066924     2013.0     NaN             49             Documentary
#
# [274351 rows x 9 columns]

# %% [markdown]
# Eliminate movies that include "Documentary" in genre

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('Documentary',case=False,na=False)

# %%
basics= basics[~is_documentary]

# %%
basics
# Out:
#              tconst titleType  \
# 11636     tt0011801     movie
# 15176     tt0015414     movie
# 34801     tt0035423     movie
# 61113     tt0062336     movie
# 67487     tt0068865     movie
# ...             ...       ...
# 10066740  tt9916362     movie
# 10066772  tt9916428     movie
# 10066824  tt9916538     movie
# 10066904  tt9916706     movie
# 10066914  tt9916730     movie
#
#                                                primaryTitle  \
# 11636                                      Tötet nicht mehr
# 15176                                La tierra de los toros
# 34801                                        Kate & Leopold
# 61113     The Tango of the Widower and Its Distorting Mi...
# 67487                                   Lives of Performers
# ...                                                     ...
# 10066740                                              Coven
# 10066772                                The Secret of China
# 10066824                                Kuambil Lagi Hatiku
# 10066904                                    Dankyavar Danka
# 10066914                                             6 Gunn
#
#                                       originalTitle isAdult  startYear  \
# 11636                              Tötet nicht mehr       0     2019.0
# 15176                        La tierra de los toros       0     2000.0
# 34801                                Kate & Leopold       0     2001.0
# 61113     El tango del viudo y su espejo deformante       0     2020.0
# 67487                           Lives of Performers       0     2016.0
# ...                                             ...     ...        ...
# 10066740                                   Akelarre       0     2020.0
# 10066772               Hong xing zhao yao Zhong guo       0     2019.0
# 10066824                        Kuambil Lagi Hatiku       0     2019.0
# 10066904                            Dankyavar Danka       0     2013.0
# 10066914                                     6 Gunn       0     2017.0
#
#          endYear runtimeMinutes                  genres
# 11636        NaN            NaN            Action,Crime
# 15176        NaN             60                     NaN
# 34801        NaN            118  Comedy,Fantasy,Romance
# 61113        NaN             70                   Drama
# 67487        NaN             90                   Drama
# ...          ...            ...                     ...
# 10066740     NaN             92           Drama,History
# 10066772     NaN            NaN   Adventure,History,War
# 10066824     NaN            123                   Drama
# 10066904     NaN            NaN                  Comedy
# 10066914     NaN            116                   Drama
#
# [187340 rows x 9 columns]

# %% [markdown]
# Keep only US movies

# %%
   # Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(akas['titleId']) 
basics = basics[keepers]

# %%
basics
# Out:
#              tconst titleType  \
# 34801     tt0035423     movie
# 61113     tt0062336     movie
# 67487     tt0068865     movie
# 67665     tt0069049     movie
# 86792     tt0088751     movie
# ...             ...       ...
# 10066507  tt9915872     movie
# 10066647  tt9916170     movie
# 10066656  tt9916190     movie
# 10066740  tt9916362     movie
# 10066772  tt9916428     movie
#
#                                                primaryTitle  \
# 34801                                        Kate & Leopold
# 61113     The Tango of the Widower and Its Distorting Mi...
# 67487                                   Lives of Performers
# 67665                            The Other Side of the Wind
# 86792                                     The Naked Monster
# ...                                                     ...
# 10066507                               The Last White Witch
# 10066647                                      The Rehearsal
# 10066656                                          Safeguard
# 10066740                                              Coven
# 10066772                                The Secret of China
#
#                                       originalTitle isAdult  startYear  \
# 34801                                Kate & Leopold       0     2001.0
# 61113     El tango del viudo y su espejo deformante       0     2020.0
# 67487                           Lives of Performers       0     2016.0
# 67665                    The Other Side of the Wind       0     2018.0
# 86792                             The Naked Monster       0     2005.0
# ...                                             ...     ...        ...
# 10066507              Boku no kanojo wa mahoutsukai       0     2019.0
# 10066647                                   O Ensaio       0     2019.0
# 10066656                                  Safeguard       0     2020.0
# 10066740                                   Akelarre       0     2020.0
# 10066772               Hong xing zhao yao Zhong guo       0     2019.0
#
#          endYear runtimeMinutes                     genres
# 34801        NaN            118     Comedy,Fantasy,Romance
# 61113        NaN             70                      Drama
# 67487        NaN             90                      Drama
# 67665        NaN            122                      Drama
# 86792        NaN            100       Comedy,Horror,Sci-Fi
# ...          ...            ...                        ...
# 10066507     NaN             97       Comedy,Drama,Fantasy
# 10066647     NaN             51                      Drama
# 10066656     NaN             95  Action,Adventure,Thriller
# 10066740     NaN             92              Drama,History
# 10066772     NaN            NaN      Adventure,History,War
#
# [97513 rows x 9 columns]

# %% [markdown]
# Before saving, run a final .info() for each of the dataframes to show a summary of how many movies remain and the datatypes of each feature

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97513 entries, 34801 to 10066772
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          97513 non-null  object
#  1   titleType       97513 non-null  object
#  2   primaryTitle    97513 non-null  object
#  3   originalTitle   97513 non-null  object
#  4   isAdult         97513 non-null  object
#  5   startYear       97513 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  83382 non-null  object
#  8   genres          94572 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 7.4+ MB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452564 entries, 0 to 1452563
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1452564 non-null  object
#  1   ordering         1452564 non-null  int64
#  2   title            1452564 non-null  object
#  3   region           1452564 non-null  object
#  4   language         1452564 non-null  object
#  5   types            1452564 non-null  object
#  6   attributes       1452564 non-null  object
#  7   isOriginalTitle  1452564 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 88.7+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1336675 entries, 0 to 1336674
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1336675 non-null  object
#  1   averageRating  1336675 non-null  float64
#  2   numVotes       1336675 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.6+ MB

# %% [markdown]
# Save each file to a compressed csv file "Data/" folder inside your repository.

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0           118.0  Comedy,Fantasy,Romance
# 1            70.0                   Drama
# 2            90.0                   Drama
# 3           122.0                   Drama
# 4           100.0    Comedy,Horror,Sci-Fi

# %%
## Save current dataframe to file.
akas.to_csv("Data/title-akas-us-only (5).csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title-akas-us-only (5).csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',mode='a',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1856
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2641
