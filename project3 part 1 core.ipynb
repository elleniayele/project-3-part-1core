# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'title-akas-us-only (2).csv',
#  'title.basics (1).tsv.gz',
#  'title.ratings (1).tsv.gz']

# %%
basics_url=("https://datasets.imdbws.com/title.basics.tsv.gz")
import pandas as pd
import numpy as np

# %%
akas_url="Data/title-akas-us-only (2).csv"

# %%
ratings_url='https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
basics = pd.read_csv(basics_url,sep='\t')
basics.head()
# Out:
# C:\Users\awot1\AppData\Local\Temp\ipykernel_20876\1591897761.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   basics = pd.read_csv(basics_url,sep='\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas = pd.read_csv(akas_url)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=True)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1850
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2634

# %% [markdown]
# ## reading akas file

# %% [markdown]
# ###Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
   # Filter the basics table down to only include the US by using the filter akas dataframe
keepers = ratings['tconst'].isin(akas['titleId']) 
ratings = ratings[keepers]

# %%
ratings
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000001            5.7      1989
# 1       tt0000002            5.8       265
# 4       tt0000005            6.2      2634
# 5       tt0000006            5.1       182
# 6       tt0000007            5.4       825
# ...           ...            ...       ...
# 144857  tt0229513            5.4        13
# 144859  tt0229520            7.3       692
# 144860  tt0229523            4.1        96
# 144862  tt0229528            3.2       110
# 144863  tt0229530            5.9       110
#
# [91407 rows x 3 columns]

# %% [markdown]
# - Include only movies that were released in the United States.
# - Exclude any movie with missing values for genre or runtime
# - Include only full-length movies (titleType = "movie").
# - Include only movies that were released 2000 - 2021 (include 2000 and 2021)
# - Include only fictional movies (not from the Documentary genre)

# %% [markdown]
# ## working on the basics data frame

# %% [markdown]
# ####Replace "\N" with np.nan

# %%
basics.replace({'\\N':np.nan}, inplace= True)

# %% [markdown]
# ####Eliminate movies that are null for runtimeMinutes

# %%
basics.dropna(subset= "runtimeMinutes")
# Out:
#              tconst  titleType                    primaryTitle  \
# 0         tt0000001      short                      Carmencita
# 1         tt0000002      short          Le clown et ses chiens
# 2         tt0000003      short                  Pauvre Pierrot
# 3         tt0000004      short                     Un bon bock
# 4         tt0000005      short                Blacksmith Scene
# ...             ...        ...                             ...
# 10031272  tt9916754      movie  Chico Albuquerque - Revelações
# 10031278  tt9916766  tvEpisode                  Episode #10.15
# 10031313  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 10031320  tt9916856      short                        The Wind
# 10031321  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear endYear  \
# 0                             Carmencita       0      1894     NaN
# 1                 Le clown et ses chiens       0      1892     NaN
# 2                         Pauvre Pierrot       0      1892     NaN
# 3                            Un bon bock       0      1892     NaN
# 4                       Blacksmith Scene       0      1893     NaN
# ...                                  ...     ...       ...     ...
# 10031272  Chico Albuquerque - Revelações       0      2013     NaN
# 10031278                  Episode #10.15       0      2019     NaN
# 10031313      Horrid Henry's Comic Caper       0      2014     NaN
# 10031320                        The Wind       0      2015     NaN
# 10031321       Horrid Henry Knows It All       0      2014     NaN
#
#          runtimeMinutes                       genres
# 0                     1            Documentary,Short
# 1                     5              Animation,Short
# 2                     4     Animation,Comedy,Romance
# 3                    12              Animation,Short
# 4                     1                 Comedy,Short
# ...                 ...                          ...
# 10031272             49                  Documentary
# 10031278             43  Family,Game-Show,Reality-TV
# 10031313             11   Adventure,Animation,Comedy
# 10031320             27                        Short
# 10031321             10   Adventure,Animation,Comedy
#
# [2975295 rows x 9 columns]

# %%
basics.dropna(subset='genres')
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10031317  tt9916848  tvEpisode              Episode #3.17
# 10031318  tt9916850  tvEpisode              Episode #3.19
# 10031319  tt9916852  tvEpisode              Episode #3.20
# 10031320  tt9916856      short                   The Wind
# 10031321  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894     NaN              1
# 1            Le clown et ses chiens       0      1892     NaN              5
# 2                    Pauvre Pierrot       0      1892     NaN              4
# 3                       Un bon bock       0      1892     NaN             12
# 4                  Blacksmith Scene       0      1893     NaN              1
# ...                             ...     ...       ...     ...            ...
# 10031317              Episode #3.17       0      2009     NaN            NaN
# 10031318              Episode #3.19       0      2010     NaN            NaN
# 10031319              Episode #3.20       0      2010     NaN            NaN
# 10031320                   The Wind       0      2015     NaN             27
# 10031321  Horrid Henry Knows It All       0      2014     NaN             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10031317         Action,Drama,Family
# 10031318         Action,Drama,Family
# 10031319         Action,Drama,Family
# 10031320                       Short
# 10031321  Adventure,Animation,Comedy
#
# [9580035 rows x 9 columns]

# %% [markdown]
# include only full-length movies (titleType = "movie").

# %%
basics= basics[basics['titleType']=='movie']

# %%
basics
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10031213  tt9916622     movie
# 10031240  tt9916680     movie
# 10031252  tt9916706     movie
# 10031262  tt9916730     movie
# 10031272  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 10031213        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10031240  De la ilusión al desconcierto: cine colombiano...
# 10031252                                    Dankyavar Danka
# 10031262                                             6 Gunn
# 10031272                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                Miss Jerry       0      1894
# 144                           The Corbett-Fitzsimmons Fight       0      1897
# 498                                                Bohemios       0      1905
# 570                             The Story of the Kelly Gang       0      1906
# 587                                       L'enfant prodigue       0      1907
# ...                                                     ...     ...       ...
# 10031213        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10031240  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10031252                                    Dankyavar Danka       0      2013
# 10031262                                             6 Gunn       0      2017
# 10031272                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 498          NaN            100                         NaN
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# ...          ...            ...                         ...
# 10031213     NaN             57                 Documentary
# 10031240     NaN            100                 Documentary
# 10031252     NaN            NaN                      Comedy
# 10031262     NaN            116                       Drama
# 10031272     NaN             49                 Documentary
#
# [651952 rows x 9 columns]

# %% [markdown]
# keep startYear 2000-2021

# %%
basics= basics.astype({'startYear':'float'})

# %%
basics=basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]

# %%
basics
# Out:
#              tconst titleType  \
# 11636     tt0011801     movie
# 13082     tt0013274     movie
# 15177     tt0015414     movie
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# ...             ...       ...
# 10031213  tt9916622     movie
# 10031240  tt9916680     movie
# 10031252  tt9916706     movie
# 10031262  tt9916730     movie
# 10031272  tt9916754     movie
#
#                                                primaryTitle  \
# 11636                                      Tötet nicht mehr
# 13082                           Istoriya grazhdanskoy voyny
# 15177                                La tierra de los toros
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# ...                                                     ...
# 10031213        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10031240  De la ilusión al desconcierto: cine colombiano...
# 10031252                                    Dankyavar Danka
# 10031262                                             6 Gunn
# 10031272                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult  \
# 11636                                      Tötet nicht mehr       0
# 13082                           Istoriya grazhdanskoy voyny       0
# 15177                                La tierra de los toros       0
# 34802                                        Kate & Leopold       0
# 61114             El tango del viudo y su espejo deformante       0
# ...                                                     ...     ...
# 10031213        Rodolpho Teóphilo - O Legado de um Pioneiro       0
# 10031240  De la ilusión al desconcierto: cine colombiano...       0
# 10031252                                    Dankyavar Danka       0
# 10031262                                             6 Gunn       0
# 10031272                     Chico Albuquerque - Revelações       0
#
#           startYear endYear runtimeMinutes                  genres
# 11636        2019.0     NaN            NaN            Action,Crime
# 13082        2021.0     NaN             94             Documentary
# 15177        2000.0     NaN             60                     NaN
# 34802        2001.0     NaN            118  Comedy,Fantasy,Romance
# 61114        2020.0     NaN             70                   Drama
# ...             ...     ...            ...                     ...
# 10031213     2015.0     NaN             57             Documentary
# 10031240     2007.0     NaN            100             Documentary
# 10031252     2013.0     NaN            NaN                  Comedy
# 10031262     2017.0     NaN            116                   Drama
# 10031272     2013.0     NaN             49             Documentary
#
# [274100 rows x 9 columns]

# %% [markdown]
# Eliminate movies that include "Documentary" in genre

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('Documentary',case=False,na=False)

# %%
basics= basics[~is_documentary]

# %%
basics
# Out:
#              tconst titleType  \
# 11636     tt0011801     movie
# 15177     tt0015414     movie
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67488     tt0068865     movie
# ...             ...       ...
# 10031088  tt9916362     movie
# 10031120  tt9916428     movie
# 10031172  tt9916538     movie
# 10031252  tt9916706     movie
# 10031262  tt9916730     movie
#
#                                                primaryTitle  \
# 11636                                      Tötet nicht mehr
# 15177                                La tierra de los toros
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67488                                   Lives of Performers
# ...                                                     ...
# 10031088                                              Coven
# 10031120                                The Secret of China
# 10031172                                Kuambil Lagi Hatiku
# 10031252                                    Dankyavar Danka
# 10031262                                             6 Gunn
#
#                                       originalTitle isAdult  startYear  \
# 11636                              Tötet nicht mehr       0     2019.0
# 15177                        La tierra de los toros       0     2000.0
# 34802                                Kate & Leopold       0     2001.0
# 61114     El tango del viudo y su espejo deformante       0     2020.0
# 67488                           Lives of Performers       0     2016.0
# ...                                             ...     ...        ...
# 10031088                                   Akelarre       0     2020.0
# 10031120               Hong xing zhao yao Zhong guo       0     2019.0
# 10031172                        Kuambil Lagi Hatiku       0     2019.0
# 10031252                            Dankyavar Danka       0     2013.0
# 10031262                                     6 Gunn       0     2017.0
#
#          endYear runtimeMinutes                  genres
# 11636        NaN            NaN            Action,Crime
# 15177        NaN             60                     NaN
# 34802        NaN            118  Comedy,Fantasy,Romance
# 61114        NaN             70                   Drama
# 67488        NaN             90                   Drama
# ...          ...            ...                     ...
# 10031088     NaN             92           Drama,History
# 10031120     NaN            NaN   Adventure,History,War
# 10031172     NaN            123                   Drama
# 10031252     NaN            NaN                  Comedy
# 10031262     NaN            116                   Drama
#
# [187129 rows x 9 columns]

# %% [markdown]
# Keep only US movies

# %%
   # Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(akas['titleId']) 
basics = basics[keepers]

# %%
basics
# Out:
#            tconst titleType  \
# 34802   tt0035423     movie
# 61114   tt0062336     movie
# 67488   tt0068865     movie
# 67666   tt0069049     movie
# 86793   tt0088751     movie
# ...           ...       ...
# 219636  tt0229326     movie
# 219649  tt0229340     movie
# 219659  tt0229354     movie
# 219667  tt0229362     movie
# 219804  tt0229513     movie
#
#                                              primaryTitle  \
# 34802                                      Kate & Leopold
# 61114   The Tango of the Widower and Its Distorting Mi...
# 67488                                 Lives of Performers
# 67666                          The Other Side of the Wind
# 86793                                   The Naked Monster
# ...                                                   ...
# 219636                             Dangers of the Ice Age
# 219649                                        Dinner Rush
# 219659                                   Dorcol-Manhattan
# 219667                                      Tha Eastsidaz
# 219804                              King of the Open Mics
#
#                                     originalTitle isAdult  startYear endYear  \
# 34802                              Kate & Leopold       0     2001.0     NaN
# 61114   El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67488                         Lives of Performers       0     2016.0     NaN
# 67666                  The Other Side of the Wind       0     2018.0     NaN
# 86793                           The Naked Monster       0     2005.0     NaN
# ...                                           ...     ...        ...     ...
# 219636                     Dangers of the Ice Age       0     2000.0     NaN
# 219649                                Dinner Rush       0     2000.0     NaN
# 219659                             Dorcol-Menhetn       0     2000.0     NaN
# 219667                              Tha Eastsidaz       0     2000.0     NaN
# 219804                      King of the Open Mics       0     2000.0     NaN
#
#        runtimeMinutes                  genres
# 34802             118  Comedy,Fantasy,Romance
# 61114              70                   Drama
# 67488              90                   Drama
# 67666             122                   Drama
# 86793             100    Comedy,Horror,Sci-Fi
# ...               ...                     ...
# 219636            NaN                     NaN
# 219649             99     Crime,Drama,Romance
# 219659            NaN    Comedy,Drama,Romance
# 219667             81            Action,Crime
# 219804            NaN                     NaN
#
# [1333 rows x 9 columns]

# %% [markdown]
# Before saving, run a final .info() for each of the dataframes to show a summary of how many movies remain and the datatypes of each feature

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1333 entries, 34802 to 219804
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1333 non-null   object
#  1   titleType       1333 non-null   object
#  2   primaryTitle    1333 non-null   object
#  3   originalTitle   1333 non-null   object
#  4   isAdult         1333 non-null   object
#  5   startYear       1333 non-null   float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  1152 non-null   object
#  8   genres          1212 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 104.1+ KB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156323 entries, 0 to 156322
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   titleId          156323 non-null  object
#  1   ordering         156323 non-null  int64
#  2   title            156323 non-null  object
#  3   region           156322 non-null  object
#  4   language         156322 non-null  object
#  5   types            156322 non-null  object
#  6   attributes       156322 non-null  object
#  7   isOriginalTitle  156322 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 9.5+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91407 entries, 0 to 144863
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         91407 non-null  object
#  1   averageRating  91407 non-null  float64
#  2   numVotes       91407 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# Save each file to a compressed csv file "Data/" folder inside your repository.

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0           118.0  Comedy,Fantasy,Romance
# 1            70.0                   Drama
# 2            90.0                   Drama
# 3           122.0                   Drama
# 4           100.0    Comedy,Horror,Sci-Fi

# %%
## Save current dataframe to file.
akas.to_csv("Data/title-akas-us-only (2).csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title-akas-us-only (2).csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',mode='a',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       265
# 2  tt0000005            6.2      2634
# 3  tt0000006            5.1       182
# 4  tt0000007            5.4       825
