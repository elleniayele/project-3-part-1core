# %%
reading for akas file, making chunks.
1
import pandas as pd
2
## Use the chunksize argument for pd.read_csv to create a TextFileReader.
3
df_reader = pd.read_csv(basics_url2, sep='\t',
4
                        low_memory=False, chunksize=100_000)
5
df_reader
6
​
7
​
<pandas.io.parsers.readers.TextFileReader at 0x2353b1ba8b0>
1
## the first row # of the next chunk is stored under ._currow
2
df_reader._currow
0
1
# Use the .get_chunk() method to extract the first chunk of rows.
2
akas = df_reader.get_chunk()
3
akas
titleId	ordering	title	region	language	types	attributes	isOriginalTitle
0	tt0000001	1	Карменсіта	UA	\N	imdbDisplay	\N	0
1	tt0000001	2	Carmencita	DE	\N	\N	literal title	0
2	tt0000001	3	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
3	tt0000001	4	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
4	tt0000001	5	Карменсита	RU	\N	imdbDisplay	\N	0
...	...	...	...	...	...	...	...	...
99995	tt0022062	1	The Inside Story	US	\N	working	\N	0
99996	tt0022062	2	The Lawless Woman	US	\N	imdbDisplay	\N	0
99997	tt0022062	3	The Lawless Woman	\N	\N	original	\N	1
99998	tt0022063	10	I nattens mörker	SE	\N	imdbDisplay	\N	0
99999	tt0022063	11	O Segredo do Advogado	PT	\N	imdbDisplay	\N	0
100000 rows × 8 columns

1
## Make the Data folder if it doesn't already exist
2
import os
3
os.makedirs('Data',exist_ok=True)
1
## Programatically saving an fname using the chunk #
2
chunk_num=1
3
fname_akas= f'Data/title_akas_chunk_{chunk_num:03d}.csv.gz'
4
fname_akas
'Data/title_akas_chunk_001.csv.gz'
1
## Save temp_df to disk using the fname.
2
akas.to_csv(fname_akas, compression='gzip')
3
## incrementing chunk_num by 1 for the next file.
4
chunk_num+=1
1
pd.read_csv(fname_akas)
C:\Users\awot1\AppData\Local\Temp\ipykernel_32416\311543800.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
  pd.read_csv(fname_akas)
Unnamed: 0	titleId	ordering	title	region	language	types	attributes	isOriginalTitle
0	0	tt0000001	1	Карменсіта	UA	\N	imdbDisplay	\N	0
1	1	tt0000001	2	Carmencita	DE	\N	\N	literal title	0
2	2	tt0000001	3	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
3	3	tt0000001	4	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
4	4	tt0000001	5	Карменсита	RU	\N	imdbDisplay	\N	0
...	...	...	...	...	...	...	...	...	...
99995	99995	tt0022062	1	The Inside Story	US	\N	working	\N	0
99996	99996	tt0022062	2	The Lawless Woman	US	\N	imdbDisplay	\N	0
99997	99997	tt0022062	3	The Lawless Woman	\N	\N	original	\N	1
99998	99998	tt0022063	10	I nattens mörker	SE	\N	imdbDisplay	\N	0
99999	99999	tt0022063	11	O Segredo do Advogado	PT	\N	imdbDisplay	\N	0
100000 rows × 9 columns

1
pd.read_csv(fname_akas, index_col=0)
2
​
C:\Users\awot1\AppData\Local\Temp\ipykernel_32416\876370043.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
  pd.read_csv(fname_akas, index_col=0)
titleId	ordering	title	region	language	types	attributes	isOriginalTitle
0	tt0000001	1	Карменсіта	UA	\N	imdbDisplay	\N	0
1	tt0000001	2	Carmencita	DE	\N	\N	literal title	0
2	tt0000001	3	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
3	tt0000001	4	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
4	tt0000001	5	Карменсита	RU	\N	imdbDisplay	\N	0
...	...	...	...	...	...	...	...	...
99995	tt0022062	1	The Inside Story	US	\N	working	\N	0
99996	tt0022062	2	The Lawless Woman	US	\N	imdbDisplay	\N	0
99997	tt0022062	3	The Lawless Woman	\N	\N	original	\N	1
99998	tt0022063	10	I nattens mörker	SE	\N	imdbDisplay	\N	0
99999	tt0022063	11	O Segredo do Advogado	PT	\N	imdbDisplay	\N	0
100000 rows × 8 columns

1
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
2
chunk_num = 1
3
df_reader = pd.read_csv(akas_url, sep='\t',
4
                        low_memory=False, chunksize=100_000)
combining the chunks in to one data frame
1
for temp_df in df_reader:
2
        #### COMBINED WORKFLOW FROM ABOVE
3
    ## Replace "\N" with np.nan
4
    temp_df.replace({'\\N':np.nan},inplace=True)
5
    temp_df = temp_df[(temp_df['region'] == 'US')]
6
     
7
    ### Saving chunk to disk
8
    fname= f'title_akas_chunk_{chunk_num:03d}.csv.gz'
9
    temp_df.to_csv(fname, compression='gzip')
10
    print(f"- Saved {fname}")
11
    
12
    ## increment chunk_num    
13
    chunk_num+=1
14
## Closing the reader now that we are done looping through the file
15
df_reader.close()
- Saved title_akas_chunk_001.csv.gz
- Saved title_akas_chunk_002.csv.gz
- Saved title_akas_chunk_003.csv.gz
- Saved title_akas_chunk_004.csv.gz
- Saved title_akas_chunk_005.csv.gz
- Saved title_akas_chunk_006.csv.gz
- Saved title_akas_chunk_007.csv.gz
- Saved title_akas_chunk_008.csv.gz
- Saved title_akas_chunk_009.csv.gz
- Saved title_akas_chunk_010.csv.gz
- Saved title_akas_chunk_011.csv.gz
- Saved title_akas_chunk_012.csv.gz
- Saved title_akas_chunk_013.csv.gz
- Saved title_akas_chunk_014.csv.gz
- Saved title_akas_chunk_015.csv.gz
- Saved title_akas_chunk_016.csv.gz
- Saved title_akas_chunk_017.csv.gz
- Saved title_akas_chunk_018.csv.gz
- Saved title_akas_chunk_019.csv.gz
- Saved title_akas_chunk_020.csv.gz
- Saved title_akas_chunk_021.csv.gz
- Saved title_akas_chunk_022.csv.gz
- Saved title_akas_chunk_023.csv.gz
- Saved title_akas_chunk_024.csv.gz
- Saved title_akas_chunk_025.csv.gz
- Saved title_akas_chunk_026.csv.gz
- Saved title_akas_chunk_027.csv.gz
- Saved title_akas_chunk_028.csv.gz
- Saved title_akas_chunk_029.csv.gz
- Saved title_akas_chunk_030.csv.gz
- Saved title_akas_chunk_031.csv.gz
- Saved title_akas_chunk_032.csv.gz
- Saved title_akas_chunk_033.csv.gz
- Saved title_akas_chunk_034.csv.gz
- Saved title_akas_chunk_035.csv.gz
- Saved title_akas_chunk_036.csv.gz
- Saved title_akas_chunk_037.csv.gz
- Saved title_akas_chunk_038.csv.gz
- Saved title_akas_chunk_039.csv.gz
- Saved title_akas_chunk_040.csv.gz
- Saved title_akas_chunk_041.csv.gz
- Saved title_akas_chunk_042.csv.gz
- Saved title_akas_chunk_344.csv.gz
- Saved title_akas_chunk_345.csv.gz
- Saved title_akas_chunk_346.csv.gz
- Saved title_akas_chunk_347.csv.gz
- Saved title_akas_chunk_348.csv.gz
- Saved title_akas_chunk_349.csv.gz
- Saved title_akas_chunk_350.csv.gz
- Saved title_akas_chunk_351.csv.gz
- Saved title_akas_chunk_352.csv.gz
- Saved title_akas_chunk_353.csv.gz
- Saved title_akas_chunk_354.csv.gz
- Saved title_akas_chunk_355.csv.gz
- Saved title_akas_chunk_356.csv.gz
- Saved title_akas_chunk_357.csv.gz
- Saved title_akas_chunk_358.csv.gz
- Saved title_akas_chunk_359.csv.gz
- Saved title_akas_chunk_360.csv.gz
- Saved title_akas_chunk_361.csv.gz
- Saved title_akas_chunk_362.csv.gz
- Saved title_akas_chunk_363.csv.gz
- Saved title_akas_chunk_364.csv.gz
- Saved title_akas_chunk_365.csv.gz
using globe to reconcatinate them in to one data frame
1
import glob
2
q = "Data/title_akas_chunk*.csv.gz"
3
chunked_files = glob.glob(q)
4
# Showing the first 5
5
chunked_files[:5]
['Data\\title_akas_chunk_001.csv.gz']
1
q = "Data/title_akas_chunk*.csv.gz"
2
chunked_files = sorted(glob.glob(q))
3
# Showing the first 5 
4
chunked_files[:5]
['Data\\title_akas_chunk_001.csv.gz']
1
# Recursive query - extra /**/ added to string
2
q = "Data/**/title_basics_chunk*.csv.gz" 
3
chunked_files = sorted(glob.glob(q, recursive=True)) 
4
# Showing the first 5 
5
chunked_files[:5]
['Data\\title_basics_chunk_001.csv.gz']
1
## Saving the final combined dataframe
2
final_fname ='Data/title_akas_combined.csv.gz'
3
df_combined.to_csv(final_fname, compression='gzip', index=False)
1
# Recursive query - extra /**/ added to string
2
q = "Data/**/title_basics_chunk*.csv.gz" 
3
chunked_files = sorted(glob.glob(q, recursive=True)) 
4
# Showing the first 5 
5
chunked_files[:5]
6
## Loading all files as df and appending to a list
7
df_list = []
8
for file in chunked_files:
9
    temp_df = pd.read_csv(file, index_col=0)
10
    df_list.append(temp_df)
11
    
12
## Concatenating the list of dfs into 1 combined
13
df_combined1 = pd.concat(df_list)
14
df_combined1
C:\Users\awot1\AppData\Local\Temp\ipykernel_32416\521999280.py:9: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
  temp_df = pd.read_csv(file, index_col=0)
titleId	ordering	title	region	language	types	attributes	isOriginalTitle
0	tt0000001	1	Карменсіта	UA	\N	imdbDisplay	\N	0
1	tt0000001	2	Carmencita	DE	\N	\N	literal title	0
2	tt0000001	3	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
3	tt0000001	4	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
4	tt0000001	5	Карменсита	RU	\N	imdbDisplay	\N	0
...	...	...	...	...	...	...	...	...
99995	tt0022063	4	The Lawyer's Secret	GB	\N	imdbDisplay	\N	0
99996	tt0022063	5	To mystikon tou dikigorou	GR	\N	\N	transliterated title	0
99997	tt0022063	6	沈黙の犯罪	JP	ja	imdbDisplay	\N	0
99998	tt0022063	7	The Lawyer's Secret	US	\N	imdbDisplay	\N	0
99999	tt0022063	8	El secreto del abogado	ES	\N	imdbDisplay	\N	0
100000 rows × 8 columns

1
final_fname
'Data/title_akas_combined.csv.gz'
1
df_combined1.info()
<class 'pandas.core.frame.DataFrame'>
Int64Index: 100000 entries, 0 to 99999
Data columns (total 8 columns):
 #   Column           Non-Null Count   Dtype 
---  ------           --------------   ----- 
 0   titleId          100000 non-null  object
 1   ordering         100000 non-null  int64 
 2   title            100000 non-null  object
 3   region           100000 non-null  object
 4   language         100000 non-null  object
 5   types            100000 non-null  object
 6   attributes       100000 non-null  object
 7   isOriginalTitle  100000 non-null  object
dtypes: int64(1), object(7)
memory usage: 6.9+ MB
reading the ratings file and chunking it.
1
import pandas as pd
2
## Use the chunksize argument for pd.read_csv to create a TextFileReader.
3
df_reader1 = pd.read_csv(basics_url3, sep='\t',
4
                        low_memory=False, chunksize=100_000)
5
df_reader1
<pandas.io.parsers.readers.TextFileReader at 0x2353b1d7ca0>
1
df_reader1._currow
0
1
# Use the .get_chunk() method to extract the first chunk of rows.
2
ratings = df_reader1.get_chunk()
3
ratings
tconst	averageRating	numVotes
0	tt0000001	5.7	1982
1	tt0000002	5.8	265
2	tt0000003	6.5	1839
3	tt0000004	5.5	178
4	tt0000005	6.2	2624
...	...	...	...
99995	tt0139096	6.1	10
99996	tt0139097	6.8	6
99997	tt0139098	6.3	65
99998	tt0139102	5.3	398
99999	tt0139105	5.2	57
100000 rows × 3 columns

checking the first chunk of rows.

1
## checking the updated ._currow
2
df_reader1._currow
100000
1
## Make the Data folder if it doesn't already exist
2
import os
3
os.makedirs('Data',exist_ok=True)
1
## Programatically saving an fname using the chunk #
2
chunk_num=1
3
fname_ratings=f'Data/title_ratings_chunk_{chunk_num:03d}.csv.gz'
4
fname_ratings
5
​
'Data/title_ratings_chunk_001.csv.gz'
1
## Save fname_ratings to disk using the fname.
2
ratings.to_csv(fname_ratings, compression='gzip')
3
## incrementing chunk_num by 1 for the next file.
4
chunk_num+=1
1
pd.read_csv(fname_ratings, index_col=0)
tconst	averageRating	numVotes
0	tt0000001	5.7	1982
1	tt0000002	5.8	265
2	tt0000003	6.5	1839
3	tt0000004	5.5	178
4	tt0000005	6.2	2624
...	...	...	...
99995	tt0139096	6.1	10
99996	tt0139097	6.8	6
99997	tt0139098	6.3	65
99998	tt0139102	5.3	398
99999	tt0139105	5.2	57
100000 rows × 3 columns

1
basics_url3='https://datasets.imdbws.com/title.ratings.tsv.gz'
2
chunk_num = 1
3
df_reader2 = pd.read_csv(basics_url3, sep='\t',
4
                        low_memory=False, chunksize=100_000)
1
### combining the chunks in to one data frame
2
##Replace "\N" with np.nan (if any)
 temp_df2.replace({'\\N':np.nan},inplace=True)
1
for temp_df2 in df_reader2:
2
        #### COMBINED WORKFLOW FROM ABOVE
3
    ## Replace "\N" with np.nan
4
    temp_df2.replace({'\\N':np.nan},inplace=True)
5
    ### Saving chunk to disk
6
    fname= f'title_ratings_chunk_{chunk_num:03d}.csv.gz'
7
    temp_df2.to_csv(fname, compression='gzip')
8
    print(f"- Saved {fname}")
9
    
10
    ## increment chunk_num    
11
    chunk_num+=1
12
## Closing the reader now that we are done looping through the file
13
df_reader2.close()
- Saved title_ratings_chunk_001.csv.gz
- Saved title_ratings_chunk_002.csv.gz
- Saved title_ratings_chunk_003.csv.gz
- Saved title_ratings_chunk_004.csv.gz
- Saved title_ratings_chunk_005.csv.gz
- Saved title_ratings_chunk_006.csv.gz
- Saved title_ratings_chunk_007.csv.gz
- Saved title_ratings_chunk_008.csv.gz
- Saved title_ratings_chunk_009.csv.gz
- Saved title_ratings_chunk_010.csv.gz
- Saved title_ratings_chunk_011.csv.gz
- Saved title_ratings_chunk_012.csv.gz
- Saved title_ratings_chunk_013.csv.gz
- Saved title_ratings_chunk_014.csv.gz
using globe to reconcatinate them in to one data frame
1
import glob
2
q = "Data/title_ratings_chunk*.csv.gz"
3
chunked_files = glob.glob(q)
4
# Showing the first 5
5
chunked_files[:5]
['Data\\title_ratings_chunk_001.csv.gz']
1
q = "Data/title_ratings_chunk*.csv.gz"
2
chunked_files = sorted(glob.glob(q))
3
# Showing the first 5 
4
chunked_files[:5]
['Data\\title_ratings_chunk_001.csv.gz']
1
# Recursive query - extra /**/ added to string
2
q = "Data/**/title_ratings_chunk*.csv.gz" 
3
chunked_files = sorted(glob.glob(q, recursive=True)) 
4
# Showing the first 5 
5
chunked_files[:5]
['Data\\title_ratings_chunk_001.csv.gz']
1
# Recursive query - extra /**/ added to string
2
q = "Data/**/title_ratings_chunk*.csv.gz" 
3
chunked_files = sorted(glob.glob(q, recursive=True)) 
4
# Showing the first 5 
5
chunked_files[:5]
6
## Loading all files as df and appending to a list
7
df_list = []
8
for file in chunked_files:
9
    temp_df = pd.read_csv(file, index_col=0)
10
    df_list.append(temp_df)
11
    
12
## Concatenating the list of dfs into 1 combined
13
df_combined = pd.concat(df_list)
14
df_combined
tconst	averageRating	numVotes
0	tt0000001	5.7	1982
1	tt0000002	5.8	265
2	tt0000003	6.5	1839
3	tt0000004	5.5	178
4	tt0000005	6.2	2624
...	...	...	...
99995	tt0139096	6.1	10
99996	tt0139097	6.8	6
99997	tt0139098	6.3	65
99998	tt0139102	5.3	398
99999	tt0139105	5.2	57
100000 rows × 3 columns

1
final_fname
'Data/title_akas_combined.csv.gz'
1
df_combined.info()
<class 'pandas.core.frame.DataFrame'>
Int64Index: 100000 entries, 0 to 99999
Data columns (total 3 columns):
 #   Column         Non-Null Count   Dtype  
---  ------         --------------   -----  
 0   tconst         100000 non-null  object 
 1   averageRating  100000 non-null  float64
 2   numVotes       100000 non-null  int64  
dtypes: float64(1), int64(1), object(1)
memory usage: 3.1+ MB
###Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

1
   # Filter the basics table down to only include the US by using the filter akas dataframe
2
keepers = ratings['tconst'].isin(akas['titleId']) 
3
ratings = ratings[keepers]
1
ratings
tconst	averageRating	numVotes
0	tt0000001	5.7	1982
1	tt0000002	5.8	265
2	tt0000003	6.5	1839
3	tt0000004	5.5	178
4	tt0000005	6.2	2624
...	...	...	...
7459	tt0022059	5.6	775
7460	tt0022060	5.3	88
7461	tt0022061	4.8	28
7462	tt0022062	5.0	16
7463	tt0022063	6.3	65
7464 rows × 3 columns

1
# example making new folder with os
2
import os
3
os.makedirs('Data/',exist_ok=True) 
4
# Confirm folder created
5
os.listdir("Data/")
['.ipynb_checkpoints',
 'title.akas.csv.gz',
 'title_akas_chunk_001.csv.gz',
 'title_akas_combined.csv.gz',
 'title_basics.csv.gz',
 'title_basics_chunk_001.csv.gz',
 'title_ratings_chunk_001.csv.gz']
1
## Save current dataframe to file.
2
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
1
# Open saved file and preview again
2
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
3
ratings.head()
tconst	averageRating	numVotes
0	tt0000001	5.7	1982
1	tt0000002	5.8	265
2	tt0000003	6.5	1839
3	tt0000004	5.5	178
4	tt0000005	6.2	2624
1
## Save current dataframe to file.
2
ratings.to_csv("Data/title.ratings.csv.gz",compression='gzip',index=False)
working on the basics data frame
####Replace "\N" with np.nan

1
basics.replace({'\\N':np.nan}, inplace= True)
####Eliminate movies that are null for runtimeMinutes

1
basics.dropna(subset= "runtimeMinutes")
tconst	titleType	primaryTitle	originalTitle	isAdult	startYear	endYear	runtimeMinutes	genres
0	tt0000001	short	Carmencita	Carmencita	0	1894	NaN	1	Documentary,Short
1	tt0000002	short	Le clown et ses chiens	Le clown et ses chiens	0	1892	NaN	5	Animation,Short
2	tt0000003	short	Pauvre Pierrot	Pauvre Pierrot	0	1892	NaN	4	Animation,Comedy,Romance
3	tt0000004	short	Un bon bock	Un bon bock	0	1892	NaN	12	Animation,Short
4	tt0000005	short	Blacksmith Scene	Blacksmith Scene	0	1893	NaN	1	Comedy,Short
...	...	...	...	...	...	...	...	...	...
21706	tt0022059	movie	Laughing Sinners	Laughing Sinners	0	1931	NaN	72	Drama,Romance
21707	tt0022060	movie	Law of the Rio Grande	Law of the Rio Grande	0	1931	NaN	57	Western
21708	tt0022061	movie	The Law of the Tong	The Law of the Tong	0	1931	NaN	61	Crime,Drama
21709	tt0022062	movie	The Lawless Woman	The Lawless Woman	0	1931	NaN	63	Crime,Drama
21710	tt0022063	movie	The Lawyer's Secret	The Lawyer's Secret	0	1931	NaN	70	Crime,Drama
13673 rows × 9 columns

1
basics.dropna(subset='genres')
tconst	titleType	primaryTitle	originalTitle	isAdult	startYear	endYear	runtimeMinutes	genres
0	tt0000001	short	Carmencita	Carmencita	0	1894	NaN	1	Documentary,Short
1	tt0000002	short	Le clown et ses chiens	Le clown et ses chiens	0	1892	NaN	5	Animation,Short
2	tt0000003	short	Pauvre Pierrot	Pauvre Pierrot	0	1892	NaN	4	Animation,Comedy,Romance
3	tt0000004	short	Un bon bock	Un bon bock	0	1892	NaN	12	Animation,Short
4	tt0000005	short	Blacksmith Scene	Blacksmith Scene	0	1893	NaN	1	Comedy,Short
...	...	...	...	...	...	...	...	...	...
9971214	tt9916848	tvEpisode	Episode #3.17	Episode #3.17	0	2009	NaN	NaN	Action,Drama,Family
9971215	tt9916850	tvEpisode	Episode #3.19	Episode #3.19	0	2010	NaN	NaN	Action,Drama,Family
9971216	tt9916852	tvEpisode	Episode #3.20	Episode #3.20	0	2010	NaN	NaN	Action,Drama,Family
9971217	tt9916856	short	The Wind	The Wind	0	2015	NaN	27	Short
9971218	tt9916880	tvEpisode	Horrid Henry Knows It All	Horrid Henry Knows It All	0	2014	NaN	10	Adventure,Animation,Comedy
9523356 rows × 9 columns
